# %% [markdown]
# <a href="https://colab.research.google.com/github/ndwiapriliamarbun/PemogramanDasar/blob/main/pertemuan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jawaban Latihan 1
tegangan = 18
arus = 6
jenis_sel = "Monocrytalline"

print(tegangan, arus, jenis_sel)

# Jawaban Latihan 2
nama_komponen = "kapasitor"
stok = 100
kapasitas = 45.5
apakah_polar = True

print(type(nama_komponen))
print(type(stok))
print(type(kapasitas))
print(type(apakah_polar))


# Jawaban Latihan 3
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_panel = 48.5
sedang_beroperasi = True

print(type(nama_unit))
print(type(jumlah_panel))
print(type(tegangan))
print(type(sedang_beroperasi))

# Jawaban Latihan 4

tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]
print("pertama:", tegangan_harian[0])
print("terakhir:", tegangan_harian[-1])
tegangan_harian.append(220)
print("jumlah_data:", len(tegangan_harian))

print(tegangan_harian[0], tegangan_harian[5])
tegangan_harian.append(220)
print(tegangan_harian)
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]
print(len(tegangan_harian))


# Jawaban Latihan 5
motor_listrik = {
"nama": "motor_listrik",
"daya_kW": 5.5,
"teganagan_V": 380,
"rpm": 1450,
}
print("nama:", motor_listrik["nama"])
motor_listrik['rpm'] = 1500
print("spesifik_terbaru:", motor_listrik)



# Jawaban Latihan 6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]

print("unit_kedua:", pembangkit[1]["nama"])
pembangkit[0]["status"] ="pemeliharaan"
pembangkit.append({"nama" :"unit-4", "kapasitas_MW": 120, "status": "operasi"})
print(pembangkit)
# Out:
# 18 6 Monocrytalline
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>
# pertama: 217.5
# terakhir: 216.9
# jumlah_data: 7
# 217.5 216.9
# [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 220, 220]
# 6
# nama: motor_listrik
# spesifik_terbaru: {'nama': 'motor_listrik', 'daya_kW': 5.5, 'teganagan_V': 380, 'rpm': 1500}
# unit_kedua: Unit-2
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'pemeliharaan'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}, {'nama': 'unit-4', 'kapasitas_MW': 120, 'status': 'operasi'}]
